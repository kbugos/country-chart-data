# %% [markdown]
# Reference: https://github.com/guoguo12/billboard-charts

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install billboard.py
# Out:
# Requirement already satisfied: billboard.py in /anaconda3/lib/python3.7/site-packages (5.2.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /anaconda3/lib/python3.7/site-packages (from billboard.py) (4.7.1)
# Requirement already satisfied: requests>=2.2.1 in /anaconda3/lib/python3.7/site-packages (from billboard.py) (2.22.0)
# Requirement already satisfied: soupsieve>=1.2 in /anaconda3/lib/python3.7/site-packages (from beautifulsoup4>=4.4.1->billboard.py) (1.9.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.2.1->billboard.py) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.2.1->billboard.py) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.2.1->billboard.py) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.2.1->billboard.py) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /anaconda3/lib/python3.7/site-packages (2.4.4)
# Requirement already satisfied: requests>=1.0 in /anaconda3/lib/python3.7/site-packages (from spotipy) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=1.0->spotipy) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=1.0->spotipy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=1.0->spotipy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=1.0->spotipy) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from credentials import *

# %%
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Import Country Airplay chart from the week of September 28, 2019

chart = billboard.ChartData('country-airplay', date='2019-09-28')

# %%
chart.entries[0:5]
# Out:
# [billboard.ChartEntry(title='Living', artist='Dierks Bentley'),
#  billboard.ChartEntry(title="I Don't Know About You", artist='Chris Lane'),
#  billboard.ChartEntry(title="Knockin' Boots", artist='Luke Bryan'),
#  billboard.ChartEntry(title='Southbound', artist='Carrie Underwood'),
#  billboard.ChartEntry(title="The Ones That Didn't Make It Back Home", artist='Justin Moore')]

# %%
# Create new dataframe for Billboard Chart Data

chart_df = pd.DataFrame(columns=['song_title','artist','rank','date'])
max_allowed = 312
attempt = 0

while chart.previousDate:
    attempt +=1
    #Stops running after 5 years worth of data
    if attempt < max_allowed:
        for i in range(0,60):
            df = pd.DataFrame({'song_title':[chart[i].title], 'artist':[chart[i].artist], 'rank':[chart[i].rank], 'date':[chart.date]})
            chart_df = chart_df.append(df, ignore_index=True)
        #Sets chart date to previous week so it can pull in that week's data next
        chart=billboard.ChartData('country-airplay', chart.previousDate)
        #Sets a 5 second break between loops to prevent an error due to too many rapid requests
        time.sleep(5)
    else:
        break

# %%
chart_df.head()
# Out:
#                                song_title            artist rank        date
# 0                                  Living    Dierks Bentley    1  2019-09-28
# 1                  I Don't Know About You        Chris Lane    2  2019-09-28
# 2                          Knockin' Boots        Luke Bryan    3  2019-09-28
# 3                              Southbound  Carrie Underwood    4  2019-09-28
# 4  The Ones That Didn't Make It Back Home      Justin Moore    5  2019-09-28

# %%
# Summary statistics
chart_df.describe()
# Out:
#                 song_title        artist   rank        date
# count                18660         18660  18660       18660
# unique                 869           295     60         311
# top     Every Little Thing  Thomas Rhett     60  2017-12-09
# freq                    78           296    311          60

# %%
chart_df.head(10)
# Out:
#                                song_title                          artist  \
# 0                                  Living                  Dierks Bentley
# 1                  I Don't Know About You                      Chris Lane
# 2                          Knockin' Boots                      Luke Bryan
# 3                              Southbound                Carrie Underwood
# 4  The Ones That Didn't Make It Back Home                    Justin Moore
# 5                          Prayed For You                      Matt Stell
# 6                       Love You Too Late                   Cole Swindell
# 7                              Good Vibes                    Chris Janson
# 8               Beer Never Broke My Heart                      Luke Combs
# 9            What Happens In A Small Town  Brantley Gilbert + Lindsay Ell
#
#   rank        date
# 0    1  2019-09-28
# 1    2  2019-09-28
# 2    3  2019-09-28
# 3    4  2019-09-28
# 4    5  2019-09-28
# 5    6  2019-09-28
# 6    7  2019-09-28
# 7    8  2019-09-28
# 8    9  2019-09-28
# 9   10  2019-09-28

# %%
# Confirm dates starts at current week and goes back 5 years
chart_df.date.unique()
# Out:
# array(['2019-09-28', '2019-09-21', '2019-09-14', '2019-09-07',
#        '2019-08-31', '2019-08-24', '2019-08-17', '2019-08-10',
#        '2019-08-03', '2019-07-27', '2019-07-20', '2019-07-13',
#        '2019-07-06', '2019-06-29', '2019-06-22', '2019-06-15',
#        '2019-06-08', '2019-06-01', '2019-05-25', '2019-05-18',
#        '2019-05-11', '2019-05-04', '2019-04-27', '2019-04-20',
#        '2019-04-13', '2019-04-06', '2019-03-30', '2019-03-23',
#        '2019-03-16', '2019-03-09', '2019-03-02', '2019-02-23',
#        '2019-02-16', '2019-02-09', '2019-02-02', '2019-01-26',
#        '2019-01-19', '2019-01-12', '2019-01-05', '2018-12-29',
#        '2018-12-22', '2018-12-15', '2018-12-08', '2018-12-01',
#        '2018-11-24', '2018-11-17', '2018-11-10', '2018-11-03',
#        '2018-10-27', '2018-10-20', '2018-10-13', '2018-10-06',
#        '2018-09-29', '2018-09-22', '2018-09-15', '2018-09-08',
#        '2018-09-01', '2018-08-25', '2018-08-18', '2018-08-11',
#        '2018-08-04', '2018-07-28', '2018-07-21', '2018-07-14',
#        '2018-07-07', '2018-06-30', '2018-06-23', '2018-06-16',
#        '2018-06-09', '2018-06-02', '2018-05-26', '2018-05-19',
#        '2018-05-12', '2018-05-05', '2018-04-28', '2018-04-21',
#        '2018-04-14', '2018-04-07', '2018-03-31', '2018-03-24',
#        '2018-03-17', '2018-03-10', '2018-03-03', '2018-02-24',
#        '2018-02-17', '2018-02-10', '2018-02-03', '2018-01-27',
#        '2018-01-20', '2018-01-13', '2018-01-06', '2018-01-03',
#        '2017-12-30', '2017-12-23', '2017-12-16', '2017-12-09',
#        '2017-12-02', '2017-11-25', '2017-11-18', '2017-11-11',
#        '2017-11-04', '2017-10-28', '2017-10-21', '2017-10-14',
#        '2017-10-07', '2017-09-30', '2017-09-23', '2017-09-16',
#        '2017-09-09', '2017-09-02', '2017-08-26', '2017-08-19',
#        '2017-08-12', '2017-08-05', '2017-07-29', '2017-07-22',
#        '2017-07-15', '2017-07-08', '2017-07-01', '2017-06-24',
#        '2017-06-17', '2017-06-10', '2017-06-03', '2017-05-27',
#        '2017-05-20', '2017-05-13', '2017-05-06', '2017-04-29',
#        '2017-04-22', '2017-04-15', '2017-04-08', '2017-04-01',
#        '2017-03-25', '2017-03-18', '2017-03-11', '2017-03-04',
#        '2017-02-25', '2017-02-18', '2017-02-11', '2017-02-04',
#        '2017-01-28', '2017-01-21', '2017-01-14', '2017-01-07',
#        '2016-12-31', '2016-12-24', '2016-12-17', '2016-12-10',
#        '2016-12-03', '2016-11-26', '2016-11-19', '2016-11-12',
#        '2016-11-05', '2016-10-29', '2016-10-22', '2016-10-15',
#        '2016-10-08', '2016-10-01', '2016-09-24', '2016-09-17',
#        '2016-09-10', '2016-09-03', '2016-08-27', '2016-08-20',
#        '2016-08-13', '2016-08-06', '2016-07-30', '2016-07-23',
#        '2016-07-16', '2016-07-09', '2016-07-02', '2016-06-25',
#        '2016-06-18', '2016-06-11', '2016-06-04', '2016-05-28',
#        '2016-05-21', '2016-05-14', '2016-05-07', '2016-04-30',
#        '2016-04-23', '2016-04-16', '2016-04-09', '2016-04-02',
#        '2016-03-26', '2016-03-19', '2016-03-12', '2016-03-05',
#        '2016-02-27', '2016-02-20', '2016-02-13', '2016-02-06',
#        '2016-01-30', '2016-01-23', '2016-01-16', '2016-01-09',
#        '2016-01-02', '2015-12-26', '2015-12-19', '2015-12-12',
#        '2015-12-05', '2015-11-28', '2015-11-21', '2015-11-14',
#        '2015-11-07', '2015-10-31', '2015-10-24', '2015-10-17',
#        '2015-10-10', '2015-10-03', '2015-09-26', '2015-09-19',
#        '2015-09-12', '2015-09-05', '2015-08-29', '2015-08-22',
#        '2015-08-15', '2015-08-08', '2015-08-01', '2015-07-25',
#        '2015-07-18', '2015-07-11', '2015-07-04', '2015-06-27',
#        '2015-06-20', '2015-06-13', '2015-06-06', '2015-05-30',
#        '2015-05-23', '2015-05-16', '2015-05-09', '2015-05-02',
#        '2015-04-25', '2015-04-18', '2015-04-11', '2015-04-04',
#        '2015-03-28', '2015-03-21', '2015-03-14', '2015-03-07',
#        '2015-02-28', '2015-02-21', '2015-02-14', '2015-02-07',
#        '2015-01-31', '2015-01-24', '2015-01-17', '2015-01-10',
#        '2015-01-03', '2014-12-27', '2014-12-20', '2014-12-13',
#        '2014-12-06', '2014-11-29', '2014-11-22', '2014-11-15',
#        '2014-11-08', '2014-11-01', '2014-10-25', '2014-10-18',
#        '2014-10-11', '2014-10-04', '2014-09-27', '2014-09-20',
#        '2014-09-13', '2014-09-06', '2014-08-30', '2014-08-23',
#        '2014-08-16', '2014-08-09', '2014-08-02', '2014-07-26',
#        '2014-07-19', '2014-07-12', '2014-07-05', '2014-06-28',
#        '2014-06-21', '2014-06-14', '2014-06-07', '2014-05-31',
#        '2014-05-24', '2014-05-17', '2014-05-10', '2014-05-03',
#        '2014-04-26', '2014-04-19', '2014-04-12', '2014-04-05',
#        '2014-03-29', '2014-03-22', '2014-03-15', '2014-03-08',
#        '2014-03-01', '2014-02-22', '2014-02-15', '2014-02-08',
#        '2014-02-01', '2014-01-25', '2014-01-18', '2014-01-11',
#        '2014-01-04', '2013-12-28', '2013-12-21', '2013-12-14',
#        '2013-12-07', '2013-11-30', '2013-11-23', '2013-11-16',
#        '2013-11-09', '2013-11-02', '2013-10-26'], dtype=object)

# %%
# Drop duplicates, keeping only the highest ranking week for each song

chart_df = chart_df.sort_values(by='rank', ascending=True).drop_duplicates(subset='song_title')

# %%
# Reset index after dropping rows
chart_df.reset_index(drop=True, inplace=True)

# %%
# Summary statistics - confirm row count is lower, as expected
chart_df.describe()
# Out:
#                  song_title      artist  rank        date
# count                   869         869   869         869
# unique                  869         294    60         293
# top     Written In The Sand  Luke Bryan     1  2019-09-28
# freq                      1          17   207          39

# %%
# Clean artist names to allow songs to match with Spotify data

for i in range(len(chart_df)-1):
    if 'Featuring' in chart_df.artist[i]:
        chart_df.artist[i]=chart_df.artist[i].split("Featuring", maxsplit=1)[0]
    if 'With' in chart_df.artist[i]:
        chart_df.artist[i]=chart_df.artist[i].split("With", maxsplit=1)[0]
    if 'Duet' in chart_df.artist[i]:
        chart_df.artist[i]=chart_df.artist[i].split("Duet", maxsplit=1)[0]
    if ',' in chart_df.artist[i]:
        chart_df.artist[i]=chart_df.artist[i].split(",", maxsplit=1)[0]
    if '+' in chart_df.artist[i]:
        chart_df.artist[i]=chart_df.artist[i].split(",", maxsplit=1)[0]
    if  chart_df.artist[i]=='David Lee Murphy & Kenny Chesney':
        chart_df.artist[i]='David Lee Murphy'
    if  chart_df.artist[i]=='Tim McGraw & Faith Hill':
        chart_df.artist[i]='Tim McGraw'
    if  chart_df.artist[i]=='Jerrod Niemann & Lee Brice':
        chart_df.artist[i]='Jerrod Niemann'
    if  chart_df.artist[i]=='Reba McEntire & Lauren Daigle':
        chart_df.artist[i]='Reba McEntire'
    if  chart_df.artist[i]=='Bebe Rexha & Florida Georgia Line':
        chart_df.artist[i]='Bebe Rexha'
    if  chart_df.artist[i]=='Garth Brooks & Blake Shelton':
        chart_df.artist[i]='Garth Brooks'
    if  chart_df.artist[i]=='Willie Robertson & Luke Bryan':
        chart_df.artist[i]='Willie Robertson'

# %%
# Remove songs not on Spotify

chart_df = chart_df[chart_df.artist != 'Garth Brooks']
chart_df = chart_df[chart_df.artist != 'Tucker Beathard']
chart_df = chart_df[chart_df.artist != 'Candi Carpenter']
chart_df = chart_df[chart_df.song_title != 'A Few More Cowboys']
chart_df = chart_df[chart_df.song_title != 'PrizeFighter']
chart_df = chart_df[chart_df.song_title != 'Just Another Love Song']
chart_df = chart_df[chart_df.song_title != 'One Night Between Friends']
chart_df = chart_df[chart_df.song_title != 'Santa Baby']

# %%
# Reset index after dropping rows
chart_df.reset_index(drop=True, inplace=True)

# %%
chart_df.head()
# Out:
#                  song_title          artist rank        date
# 0                    Living  Dierks Bentley    1  2019-09-28
# 1  Sunrise, Sunburn, Sunset      Luke Bryan    1  2018-09-22
# 2           Burnin' It Down    Jason Aldean    1  2014-11-08
# 3        Leave The Night On        Sam Hunt    1  2014-11-15
# 4              Life Changes    Thomas Rhett    1  2018-09-08

# %%
chart_df
# Out:
#                    song_title          artist rank        date
# 0                      Living  Dierks Bentley    1  2019-09-28
# 1    Sunrise, Sunburn, Sunset      Luke Bryan    1  2018-09-22
# 2             Burnin' It Down    Jason Aldean    1  2014-11-08
# 3          Leave The Night On        Sam Hunt    1  2014-11-15
# 4                Life Changes    Thomas Rhett    1  2018-09-08
# ..                        ...             ...  ...         ...
# 848          Keep On Truckin'      Tim McGraw   60  2014-10-04
# 849          Smile That Smile     Weston Burt   60  2014-02-22
# 850                Headphones      Jackie Lee   60  2015-08-01
# 851               Light Me Up   Kristian Bush   60  2015-09-12
# 852       Doin' Country Right   David Fanning   60  2015-03-21
#
# [853 rows x 4 columns]

# %%
# Create four blank lists
# Then append to them using the results from the Spotify search of the songs in the Billboard chart dataframe
# Create a none counter to identify every time the search fails to return any results

artist_name=[]
track_name=[]
track_id=[]
popularity=[]
None_counter=0
for i in range(len(chart_df)-1):
    track_results = sp.search(q=('artist:' + chart_df.artist[i] + ' track: ' + chart_df.song_title[i]), limit=1, type='track')
    for i, t in enumerate(track_results['tracks']['items']):
        if t == None:
            None_counter = None_counter + 1
        else:
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            popularity.append(t['popularity'])

# %%
# Verify all songs matched with Spotify results

None_counter
# Out:
# 0

# %%
# Create a dataframe from the four lists

spotify_df = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
print(spotify_df.shape)
spotify_df.head()
# Out:
# (812, 4)
#       artist_name                track_name                track_id  \
# 0  Dierks Bentley                    Living  54K7AZoGpQklpygKrxZlKN
# 1      Luke Bryan  Sunrise, Sunburn, Sunset  53yTYusPQJ1AApL1hi0Dnc
# 2    Jason Aldean           Burnin' It Down  5HJqpDspKDKwQpLjvkcIsD
# 3        Sam Hunt        Leave The Night On  3wx2kQWPn9p5UppQbNhPAk
# 4    Thomas Rhett              Life Changes  4Vxu50qVrQcycjRyJQaZLC
#
#    popularity
# 0          75
# 1          70
# 2          65
# 3          66
# 4          70

# %%
audio_features_df = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

for i in range(len(spotify_df)-1):
    audio_features_df = audio_features_df.append(sp.audio_features(tracks=[spotify_df.track_id[i]]))

# %%
audio_features_df.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.517   0.813   1    -6.325    1       0.0558        0.0153
# 0         0.472   0.884   9    -2.306    1       0.0584        0.1850
# 0         0.681   0.795   6    -6.652    1       0.0490        0.3050
# 0         0.514   0.951   9    -3.813    1       0.0603        0.0951
# 0         0.687   0.842   7    -4.382    1       0.0580        0.1050
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.1060    0.444   83.005  audio_features
# 0                0    0.1780    0.718  159.960  audio_features
# 0         9.41e-06    0.1090    0.640  135.939  audio_features
# 0                0    0.3490    0.838  171.960  audio_features
# 0                0    0.0436    0.778   87.968  audio_features
#
#                        id                                   uri  \
# 0  54K7AZoGpQklpygKrxZlKN  spotify:track:54K7AZoGpQklpygKrxZlKN
# 0  53yTYusPQJ1AApL1hi0Dnc  spotify:track:53yTYusPQJ1AApL1hi0Dnc
# 0  5HJqpDspKDKwQpLjvkcIsD  spotify:track:5HJqpDspKDKwQpLjvkcIsD
# 0  3wx2kQWPn9p5UppQbNhPAk  spotify:track:3wx2kQWPn9p5UppQbNhPAk
# 0  4Vxu50qVrQcycjRyJQaZLC  spotify:track:4Vxu50qVrQcycjRyJQaZLC
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/54K7AZoGpQkl...
# 0  https://api.spotify.com/v1/tracks/53yTYusPQJ1A...
# 0  https://api.spotify.com/v1/tracks/5HJqpDspKDKw...
# 0  https://api.spotify.com/v1/tracks/3wx2kQWPn9p5...
# 0  https://api.spotify.com/v1/tracks/4Vxu50qVrQcy...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/54K7...      222147
# 0  https://api.spotify.com/v1/audio-analysis/53yT...      216093
# 0  https://api.spotify.com/v1/audio-analysis/5HJq...      219160
# 0  https://api.spotify.com/v1/audio-analysis/3wx2...      192160
# 0  https://api.spotify.com/v1/audio-analysis/4Vxu...      190227
#
#   time_signature
# 0              4
# 0              4
# 0              4
# 0              4
# 0              4

# %%
# Merge audio features dataframe with basic Spotify dataframe

track_df = audio_features_df.merge(spotify_df, left_on='id', right_on='track_id')

# %%
track_df.shape
# Out:
# (811, 22)

# %%
track_df.columns.tolist()
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'artist_name',
#  'track_name',
#  'track_id',
#  'popularity']

# %%
column_order = ['track_id',
'artist_name',
'track_name',
'rank',
'danceability',
'energy',
'key',
'loudness',
'mode',
'speechiness',
'acousticness',
'instrumentalness',
'liveness',
'valence',
'tempo',
'duration_ms',
'time_signature']

# %%
# Reorder columns

track_df = track_df.reindex(columns=column_order)

# %%
# Drop row with artist = The Karaoke Channel, as it is not correctly matched to the charting song

track_df = track_df[track_df['artist_name'] != 'The Karaoke Channel']

# %%
# Reset index after dropping row

track_df.reset_index(drop=True, inplace=True)

# %%
# Manually create a list of duos/groups

groups=['Maddie & Tae',
 'Old Dominion',
 'Florida Georgia Line',
 'Lady Antebellum',
 'Zac Brown Band',
 'Dan + Shay',
 'Eli Young Band',
 'Parmalee',
 'Rascal Flatts',
 'Little Big Town',
 'LANCO',
 'A Thousand Horses',
 'LOCASH',
 'Brothers Osborne',
 'Midland',
 'Thompson Square',
 'High Valley',
 'Big & Rich',
 'Runaway June',
 'The Band Perry',
 'The Swon Brothers',
 'Sugarland',
 'Gloriana',
 'Artists Of Then, Now & Forever',
 'The Cadillac Three',
 'Love and Theft',
 'The Henningsens',
 'Josh Abbott Band',
 'Montgomery Gentry',
 'Brooks & Dunn',
 'Gone West',
 'American Young',
 "Chasin' Crazy",
 'The Railers',
 'James Barker Band',
 'Radio Romance',
 'The Last Bandoleros',
 'King Calaway',
 'Waterloo Revival',
 'Pistol Annies',
 'Breaking Southwest',
 'Sir Rosevelt',
 'Everette',
 'Blackjack Billy',
 'Sister C',
 'Bobby Bones & The Raging Idiots']

# %%
# Manually create a list of artist that are female (solo or group) and mixed gender groups.

female=['Maddie & Tae', 
 'Bebe Rexha', 
 'Maren Morris', 
 'Lauren Alaina', 
 'Kelsea Ballerini', 
 'Carrie Underwood', 
 'Carly Pearce', 
 'Cam', 
 'Miranda Lambert', 
 'Jana Kramer', 
 'Taylor Swift', 
 'Cassadee Pope', 
 'Danielle Bradberry', 
 'RaeLynn',
 'Sara Evans',
 'Lindsay Ell',
 'Trisha Yearwood',
 'Jennifer Nettles',
 'Ingrid Andress',
 'Sheryl Crow',
 'Reba McEntire'
 'Ashley McBryde',
 'Kacey Musgraves',
 'Mickey Guyton',
 'Shania Twain',
 'Leah Turner',
 'Brandy Clark',
 'Caylee Hammack',
 'Natalie Stovall',
 'Clare Dunn',
 'Maggie Rose',
 'Martina McBride',
 'Lucy Hale',
 'Brooke Eden',
 'Kelleigh Bannen',
 'Kellie Pickler',
 'Kelly Clarkson',
 'Pistol Annies',
 'Lucy Angel',
 'P!nk',
 'Ashley Monroe',
 'Jillian Jacqueline',
 'Gabby Barrett',
 'Caroline Jones',
 'Rachel Wammack',
 'Jamie Lynn Spears',
 'Ashley Campbell',
 'Stephanie Quayle',
 'Shakira',
 'Kristy Lee Cook',
 'Abby Anderson',
 'LeAnn Rimes',
 'Bailey Bryan',
 'Sister C',
 'Tara Thompson']

mixed=['Lady Antebellum',
 'Little Big Town',
 'Thompson Square',
 'The Band Perry',
 'Sugarland',
 'Gloriana',
 'The Henningsens',
 'Gone West',
 'American Young',
 'The Railers',
 'Breaking Southwest',
 'Artists Of Then, Now & Forever']

# %%
# Create an is_group column using the list created above

track_df['is_group']=np.nan

for i in range(len(track_df)-1):
    if track_df['artist_name'][i] in groups:
        track_df['is_group'][i]=1
    else:
        track_df['is_group'][i]=0

# %%
track_df['is_group'].value_counts()
# Out:
# 0.0    651
# 1.0    159
# Name: is_group, dtype: int64

# %%
# Create a gender column using the lists created above

track_df['gender']=np.nan

for i in range(len(track_df)-1):
    if track_df['artist_name'][i] in female:
        track_df['gender'][i]='female'
    elif track_df['artist_name'][i] in mixed:
        track_df['gender'][i]='mixed'
    else:
        track_df['gender'][i]='male'

# %%
track_df['gender'].value_counts()
# Out:
# male      647
# female    127
# mixed      36
# Name: gender, dtype: int64

# %%
track_df.describe(include='all')
# Out:
#                       track_id   artist_name track_name  rank  danceability  \
# count                      811           811        811   0.0    811.000000
# unique                     811           224        811   NaN           NaN
# top     54RCDE1TAewECyX4WDUVm1  Jason Aldean   Homesick   NaN           NaN
# freq                         1            17          1   NaN           NaN
# mean                       NaN           NaN        NaN   NaN      0.568998
# std                        NaN           NaN        NaN   NaN      0.093859
# min                        NaN           NaN        NaN   NaN      0.169000
# 25%                        NaN           NaN        NaN   NaN      0.511000
# 50%                        NaN           NaN        NaN   NaN      0.573000
# 75%                        NaN           NaN        NaN   NaN      0.632000
# max                        NaN           NaN        NaN   NaN      0.878000
#
#             energy    key    loudness   mode  speechiness  acousticness  \
# count   811.000000  811.0  811.000000  811.0   811.000000    811.000000
# unique         NaN   12.0         NaN    2.0          NaN           NaN
# top            NaN    0.0         NaN    1.0          NaN           NaN
# freq           NaN   99.0         NaN  718.0          NaN           NaN
# mean      0.736974    NaN   -5.442958    NaN     0.047944      0.169854
# std       0.156694    NaN    1.852261    NaN     0.060612      0.201136
# min       0.062800    NaN  -17.077000    NaN     0.023000      0.000226
# 25%       0.657500    NaN   -6.289000    NaN     0.030600      0.027150
# 50%       0.777000    NaN   -5.229000    NaN     0.036600      0.088300
# 75%       0.856000    NaN   -4.251500    NaN     0.047800      0.252000
# max       0.994000    NaN   -0.698000    NaN     0.952000      0.952000
#
#         instrumentalness    liveness     valence       tempo  duration_ms  \
# count              811.0  811.000000  811.000000  811.000000        811.0
# unique             284.0         NaN         NaN         NaN        784.0
# top                  0.0         NaN         NaN         NaN     190587.0
# freq               502.0         NaN         NaN         NaN          3.0
# mean                 NaN    0.171041    0.557948  125.077390          NaN
# std                  NaN    0.114737    0.203722   31.543363          NaN
# min                  NaN    0.021200    0.067300   48.718000          NaN
# 25%                  NaN    0.097200    0.406000   97.996500          NaN
# 50%                  NaN    0.122000    0.560000  122.981000          NaN
# 75%                  NaN    0.220000    0.717000  150.111500          NaN
# max                  NaN    0.882000    0.972000  205.958000          NaN
#
#         time_signature    is_group gender
# count            811.0  810.000000    810
# unique             4.0         NaN      3
# top                4.0         NaN   male
# freq             773.0         NaN    647
# mean               NaN    0.196296    NaN
# std                NaN    0.397441    NaN
# min                NaN    0.000000    NaN
# 25%                NaN    0.000000    NaN
# 50%                NaN    0.000000    NaN
# 75%                NaN    0.000000    NaN
# max                NaN    1.000000    NaN

# %%
# Merge dataframe created above with the Billboard Chart dataframe to create a single, comprehensive dataframe

## Working on better method to do this when creating the Spotify dataframe, as this loses too many records in the matching process

track_df = pd.merge(track_df, chart_df, left_on=['track_name','artist_name'], right_on = ['song_title','artist'])

# %%
track_df.to_csv('./track_df.csv')
